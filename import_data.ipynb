# %%
import pandas as pd 
from sqlalchemy import create_engine
from time import time
import os

# %%
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-10.parquet" 
os.system(f'wget {url}')
parquet_file = pd.read_parquet("D:/other/project/data-engineering/green_tripdata_2019-10.parquet")
parquet_file.to_csv("green_tripdata_2019-10.csv")
df = pd.read_csv("green_tripdata_2019-10.csv")
df
# Out:
# C:\Users\Sina\AppData\Local\Temp\ipykernel_16780\2651818072.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("green_tripdata_2019-10.csv")
#         Unnamed: 0  VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0                0         2  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1                1         1  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2                2         1  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3                3         1  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4                4         2  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...            ...       ...                  ...                   ...
# 476381      476381         2  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382      476382         2  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383      476383         2  2019-10-31 23:02:00   2019-10-31 23:23:00
# ...

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df
# Out:
#         Unnamed: 0  VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0                0         2  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1                1         1  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2                2         1  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3                3         1  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4                4         2  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...            ...       ...                  ...                   ...
# 476381      476381         2  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382      476382         2  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383      476383         2  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384      476384         2  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385      476385         2  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'VendorID', 'lpep_pickup_datetime',
#        'lpep_dropoff_datetime', 'store_and_fwd_flag', 'RatecodeID',
#        'PULocationID', 'DOLocationID', 'passenger_count', 'trip_distance',
#        'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'ehail_fee', 'improvement_surcharge', 'total_amount', 'payment_type',
#        'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
engin = create_engine('postgresql://root:root@localhost:5432/ny_taxi_data')
engin.connect()

# %%
sql_table = pd.io.sql.get_schema(df,name='yellow_taxi_data',con=engin)

# %%
print(sql_table)

# %%
df_iter  = pd.read_csv('yellow_tripdata_2021-01.csv',iterator=True,chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# %%
len(df)

# %%
df.info()

# %%
df.head(n=0).to_sql(name='yellow_taxi',con=engin,if_exists='replace')

# %%
df.to_sql(name='yellow_taxi',con=engin,if_exists='append')

# %%
while True:
    try :
        begin = time()
        df = next(df_iter)
        df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
        df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
        df.to_sql(name='yellow_taxi',con=engin,if_exists='append')
        end = time()
    
        print(f'tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : {end-begin} SECONDS')
        
    except StopIteration:

        print('NO MORE DATA TO APPEND')
        break

# %%
query = 'SELECT * FROM yellow_taxi LIMIT 10'
pd.read_sql(sql=query,con=engin)

# %%
url_zone_data = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv'
file_name = 'zone_data.csv'
os.system(f'wget {url_zone_data} -O {file_name}')
zone_df = pd.read_csv(file_name)
zone_df.columns
# Out:
# Index(['LocationID', 'Borough', 'Zone', 'service_zone'], dtype='object')
