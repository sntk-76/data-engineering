# %%
import pandas as pd 
from sqlalchemy import create_engine
from time import time

# %%
df = pd.DataFrame(pd.read_csv("yellow_tripdata_2021-01.csv"))
df
# Out:
# C:\Users\Sina\AppData\Local\Temp\ipykernel_2056\2672595414.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.DataFrame(pd.read_csv("yellow_tripdata_2021-01.csv"))
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 2.10         1.0                  N           142
# 1                 0.20         1.0                  N           238
# 2                14.70         1.0                  N           132
# 3                10.60         1.0                  N           138
# 4                 4.94         1.0                  N            68
# ...                ...         ...                ...           ...
# 1369764           8.89         NaN                NaN           229
# 1369765           7.43         NaN                NaN            41
# 1369766           6.26         NaN                NaN            74
# 1369767          19.70         NaN                NaN           265
# 1369768           4.68         NaN                NaN            89
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  43             2         8.00   3.00      0.5        0.00
# 1                 151             2         3.00   0.50      0.5        0.00
# 2                 165             1        42.00   0.50      0.5        8.65
# 3                 132             1        29.00   0.50      0.5        6.05
# 4                  33             1        16.50   0.50      0.5        4.06
# ...               ...           ...          ...    ...      ...         ...
# 1369764           181             0        27.78   0.00      0.5        7.46
# 1369765            70             0        32.58   0.00      0.5        0.00
# 1369766           137             0        16.85   0.00      0.5        3.90
# 1369767           188             0        53.68   0.00      0.5        0.00
# 1369768            61             0        25.45   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         11.80
# 1                0.00                    0.3          4.30
# 2                0.00                    0.3         51.95
# 3                0.00                    0.3         36.35
# 4                0.00                    0.3         24.36
# ...               ...                    ...           ...
# 1369764          0.00                    0.3         38.54
# 1369765          6.12                    0.3         39.50
# 1369766          0.00                    0.3         24.05
# 1369767          0.00                    0.3         54.48
# 1369768          0.00                    0.3         29.00
#
#          congestion_surcharge  airport_fee
# 0                         2.5          NaN
# 1                         0.0          NaN
# 2                         0.0          NaN
# 3                         0.0          NaN
# 4                         2.5          NaN
# ...                       ...          ...
# 1369764                   NaN          NaN
# 1369765                   NaN          NaN
# 1369766                   NaN          NaN
# 1369767                   NaN          NaN
# 1369768                   NaN          NaN
#
# [1369769 rows x 19 columns]

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 2.10         1.0                  N           142
# 1                 0.20         1.0                  N           238
# 2                14.70         1.0                  N           132
# 3                10.60         1.0                  N           138
# 4                 4.94         1.0                  N            68
# ...                ...         ...                ...           ...
# 1369764           8.89         NaN                NaN           229
# 1369765           7.43         NaN                NaN            41
# 1369766           6.26         NaN                NaN            74
# 1369767          19.70         NaN                NaN           265
# 1369768           4.68         NaN                NaN            89
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  43             2         8.00   3.00      0.5        0.00
# 1                 151             2         3.00   0.50      0.5        0.00
# 2                 165             1        42.00   0.50      0.5        8.65
# 3                 132             1        29.00   0.50      0.5        6.05
# 4                  33             1        16.50   0.50      0.5        4.06
# ...               ...           ...          ...    ...      ...         ...
# 1369764           181             0        27.78   0.00      0.5        7.46
# 1369765            70             0        32.58   0.00      0.5        0.00
# 1369766           137             0        16.85   0.00      0.5        3.90
# 1369767           188             0        53.68   0.00      0.5        0.00
# 1369768            61             0        25.45   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         11.80
# 1                0.00                    0.3          4.30
# 2                0.00                    0.3         51.95
# 3                0.00                    0.3         36.35
# 4                0.00                    0.3         24.36
# ...               ...                    ...           ...
# 1369764          0.00                    0.3         38.54
# 1369765          6.12                    0.3         39.50
# 1369766          0.00                    0.3         24.05
# 1369767          0.00                    0.3         54.48
# 1369768          0.00                    0.3         29.00
#
#          congestion_surcharge  airport_fee
# 0                         2.5          NaN
# 1                         0.0          NaN
# 2                         0.0          NaN
# 3                         0.0          NaN
# 4                         2.5          NaN
# ...                       ...          ...
# 1369764                   NaN          NaN
# 1369765                   NaN          NaN
# 1369766                   NaN          NaN
# 1369767                   NaN          NaN
# 1369768                   NaN          NaN
#
# [1369769 rows x 19 columns]

# %%
engin = create_engine('postgresql://root:root@localhost:5432/ny_taxi_data')
engin.connect()

# %%
sql_table = pd.io.sql.get_schema(df,name='yellow_taxi_data',con=engin)

# %%
print(sql_table)
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df_iter  = pd.read_csv('yellow_tripdata_2021-01.csv',iterator=True,chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# %%
len(df)
# Out:
# 100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               100000 non-null  int64
#  1   tpep_pickup_datetime   100000 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  100000 non-null  datetime64[ns]
#  3   passenger_count        100000 non-null  float64
#  4   trip_distance          100000 non-null  float64
#  5   RatecodeID             100000 non-null  float64
#  6   store_and_fwd_flag     100000 non-null  object
#  7   PULocationID           100000 non-null  int64
#  8   DOLocationID           100000 non-null  int64
#  9   payment_type           100000 non-null  int64
#  10  fare_amount            100000 non-null  float64
#  11  extra                  100000 non-null  float64
#  12  mta_tax                100000 non-null  float64
#  13  tip_amount             100000 non-null  float64
#  14  tolls_amount           100000 non-null  float64
#  15  improvement_surcharge  100000 non-null  float64
#  16  total_amount           100000 non-null  float64
#  17  congestion_surcharge   100000 non-null  float64
#  18  airport_fee            0 non-null       float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# memory usage: 14.5+ MB

# %%
df.head(n=0).to_sql(name='yellow_taxi',con=engin,if_exists='replace')
# Out:
# 0

# %%
df.to_sql(name='yellow_taxi',con=engin,if_exists='append')
# Out:
# 1000

# %%
while True:
    try :
        begin = time()
        df = next(df_iter)
        df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
        df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
        df.to_sql(name='yellow_taxi',con=engin,if_exists='append')
        end = time()
    
        print(f'tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : {end-begin} SECONDS')
        
    except StopIteration:

        print('NO MORE DATA TO APPEND')
        break
# Out:
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.932989597320557 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.77713179588318 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.434738159179688 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 16.810763120651245 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 16.876986742019653 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.96866774559021 SECONDS
# C:\Users\Sina\AppData\Local\Temp\ipykernel_2056\3051821174.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.531524658203125 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 18.200056791305542 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.913037061691284 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 18.498542308807373 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.75554656982422 SECONDS
# C:\Users\Sina\AppData\Local\Temp\ipykernel_2056\3051821174.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 17.989686489105225 SECONDS
# tHE NEW CHUNCK WAS ADDED TO THE DATABASE IN : 13.246776103973389 SECONDS
# NO MORE DATA TO APPEND

# %%
query = 'SELECT * FROM yellow_taxi LIMIT 10'
pd.read_sql(sql=query,con=engin)
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1      1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2      2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3      3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4      4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# 5      5         1  2021-01-01 00:16:29   2021-01-01 00:24:30
# 6      6         1  2021-01-01 00:00:28   2021-01-01 00:17:28
# 7      7         1  2021-01-01 00:12:29   2021-01-01 00:30:34
# 8      8         1  2021-01-01 00:39:16   2021-01-01 01:00:13
# 9      9         1  2021-01-01 00:26:12   2021-01-01 00:39:46
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           2.10         1.0                  N
# 1              1.0           0.20         1.0                  N
# 2              1.0          14.70         1.0                  N
# 3              0.0          10.60         1.0                  N
# 4              1.0           4.94         1.0                  N
# 5              1.0           1.60         1.0                  N
# 6              1.0           4.10         1.0                  N
# 7              1.0           5.70         1.0                  N
# 8              1.0           9.10         1.0                  N
# 9              2.0           2.70         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           142            43             2          8.0    3.0      0.5
# 1           238           151             2          3.0    0.5      0.5
# 2           132           165             1         42.0    0.5      0.5
# 3           138           132             1         29.0    0.5      0.5
# 4            68            33             1         16.5    0.5      0.5
# 5           224            68             1          8.0    3.0      0.5
# 6            95           157             2         16.0    0.5      0.5
# 7            90            40             2         18.0    3.0      0.5
# 8            97           129             4         27.5    0.5      0.5
# 9           263           142             1         12.0    3.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        0.00           0.0                    0.3         11.80
# 1        0.00           0.0                    0.3          4.30
# 2        8.65           0.0                    0.3         51.95
# 3        6.05           0.0                    0.3         36.35
# 4        4.06           0.0                    0.3         24.36
# 5        2.35           0.0                    0.3         14.15
# 6        0.00           0.0                    0.3         17.30
# 7        0.00           0.0                    0.3         21.80
# 8        0.00           0.0                    0.3         28.80
# 9        3.15           0.0                    0.3         18.95
#
#    congestion_surcharge airport_fee
# 0                   2.5        None
# 1                   0.0        None
# 2                   0.0        None
# 3                   0.0        None
# 4                   2.5        None
# 5                   2.5        None
# 6                   0.0        None
# 7                   2.5        None
# 8                   0.0        None
# 9                   2.5        None
